# %% [markdown]
# <a href="https://colab.research.google.com/github/scss-2022/SanjeevChauhan/blob/main/SI_aasign_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import random 
import matplotlib.pyplot as plt
from numpy.core.arrayprint import printoptions
#from statistics.mode(data) as mode
import seaborn as sns
sns.set_style("darkgrid")
# Basic Statistics on the population
desint = np.random.randint(0,100,1000)
#print (desint)
desmean =  np.mean(desint)
print("Mean",desmean)
print("Median",np.median(desint))
print("Standard Deviation",np.std(desint))
print("Varience",np.var(desint))
#print("Mode : ",mode(desint))
plt.hist(desint, bins='auto')
plt.title("Histogram with 'auto' bins")
#plt.show()
#count, bins, ignored = plt.hist(desint, 10, density=True)
#plt.show()
# Out:
# Mean 52.564
# Median 54.0
# Standard Deviation 28.892350267847718
# Varience 834.767904
# Text(0.5, 1.0, "Histogram with 'auto' bins")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

n = 100
rands = np.random.rand(n)
biased = []
unbiased = []
for i in range(2, n+1):
  biased.append(np.var(rands[:i], ddof=0))
  unbiased.append(np.var(rands[:i], ddof=1))

x = np.arange(2, n+1)
plt.plot(x, biased, label="Biased")
plt.plot(x, unbiased, label="Unbiased")
plt.hlines(1/12, x[0], x[-1], label="Ground truth")
plt.xlabel("Sample size")
plt.ylabel("Variance")
plt.legend()
plt.title("Sample variance #1");
